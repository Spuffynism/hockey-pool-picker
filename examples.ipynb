# %% [markdown]
# # Hockey Pool Picker
#
# Backtest pool picking strategies from past to present seasons.

# %%
from src.hockey_pool_picker.backtest import backtest

backtest(season_start=2022)
# Out:
# Some players do not have a match between sources in season 2022-2023:
#     name_from_cap_hit_source name_from_players_stats_source
# 1                        NaN                   Adam Beckman
# 5                        NaN                     Adam Raška
# 6                        NaN                   Adam Ružička
# 8                        NaN                Aidan McDonough
# 11                       NaN               Aleksi Heponiemi
# 17                       NaN                   Alex Belzile
# 21                       NaN                Alex Galchenyuk
# 27                       NaN                   Alex Steeves
# 34                       NaN               Andreas Johnsson
# 38                       NaN                Andrew Agozzino
# 42                       NaN                  Andy Andreoff
# 47                       NaN                Anthony Richard
# 48                       NaN                    Anton Blidh
# ...

# %% [markdown]
# Pick a pool for the "next" season.

# %%
from hockey_pool_picker.pick_pool import pick_pool

pick_pool(season_start=2022)
# Out:
# Some players do not have a match between sources in season 2022-2023:
#     name_from_cap_hit_source name_from_players_stats_source
# 1                        NaN                   Adam Beckman
# 5                        NaN                     Adam Raška
# 6                        NaN                   Adam Ružička
# 8                        NaN                Aidan McDonough
# 11                       NaN               Aleksi Heponiemi
# 17                       NaN                   Alex Belzile
# 21                       NaN                Alex Galchenyuk
# 27                       NaN                   Alex Steeves
# 34                       NaN               Andreas Johnsson
# 38                       NaN                Andrew Agozzino
# 42                       NaN                  Andy Andreoff
# 47                       NaN                Anthony Richard
# 48                       NaN                    Anton Blidh
# ...

# %% [markdown]
# Run the crawler

# %%
from hockey_pool_picker.crawl import crawl

crawl()
# Out:
# /Users/nico/projects/nico/hockey-pool-picker
# (6.48%) 85/1312: https://www.hockey-reference.com/boxscores/202110250CBJ.html
